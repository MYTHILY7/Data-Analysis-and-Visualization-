# %% [markdown]
# <a href="https://colab.research.google.com/github/MYTHILY7/Data-Analysis-and-Visualization-/blob/main/mall_customers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
/content/drive/MyDrive/Colab Notebooks/Mall_bitcoin (2). csv .xlsx

# %%
mall=pd.read_csv("/content/Mall_Customers (2).csv")

# %%
mall.shape
# Out:
# (200, 5)

# %%
mall.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
mall.tail()
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83

# %%
mall.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
mall.sample(5)
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 43           44  Female   31                  39                      61
# 196         197  Female   45                 126                      28
# 146         147    Male   48                  77                      36
# 163         164  Female   31                  81                      93
# 168         169  Female   36                  87                      27

# %%
mall.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
mall.isnull().sum()
# Out:
# CustomerID                0
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
mall['Genre'] = le.fit_transform(mall['Genre'])
mall.head()
# Out:
#    CustomerID  Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1      1   19                  15                      39
# 1           2      1   21                  15                      81
# 2           3      0   20                  16                       6
# 3           4      0   23                  16                      77
# 4           5      0   31                  17                      40

# %%
mall.plot(x='Genre',y='Spending Score (1-100)',style='o')
plt.title('Genre vs Money spent')
plt.xlabel('Genre')
plt.ylabel('Money spent')
plt.show()

# %%
from sklearn.model_selection import train_test_split
y=mall.Genre
x=mall.drop('CustomerID',axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
x_train
# Out:
#      Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 134      1   20                  73                       5
# 66       0   43                  48                      50
# 26       0   45                  28                      32
# 113      1   19                  64                      46
# 168      0   36                  87                      27
# ..     ...  ...                 ...                     ...
# 67       0   68                  48                      48
# 192      1   33                 113                       8
# 117      0   49                  65                      59
# 47       0   27                  40                      47
# 172      1   36                  87                      10
#
# [160 rows x 4 columns]

# %%
y_train
# Out:
# 134    1
# 66     0
# 26     0
# 113    1
# 168    0
#       ..
# 67     0
# 192    1
# 117    0
# 47     0
# 172    1
# Name: Genre, Length: 160, dtype: int64

# %%
x_test
# Out:
#      Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 18       1   52                  23                      29
# 170      1   40                  87                      13
# 107      1   54                  63                      46
# 98       1   48                  61                      42
# 177      1   27                  88                      69
# 182      1   46                  98                      15
# 5        0   22                  17                      76
# 146      1   48                  77                      36
# 12       0   58                  20                      15
# 152      0   44                  78                      20
# 61       1   19                  46                      55
# 125      0   31                  70                      77
# 180      0   37                  97                      32
# 154      0   47                  78                      16
# 80       1   57                  54                      51
# ...

# %%
y_test
# Out:
# 18     1
# 170    1
# 107    1
# 98     1
# 177    1
# 182    1
# 5      0
# 146    1
# 12     0
# 152    0
# 61     1
# 125    0
# 180    0
# 154    0
# 80     1
# 7      0
# 33     1
# 130    1
# 37     0
# 74     1
# 183    0
# 145    1
# 45     0
# 159    0
# 60     1
# 123    1
# 179    1
# 185    1
# 122    0
# 44     0
# 16     0
# 55     1
# 150    1
# 111    0
# 22     0
# 189    0
# 129    1
# 4      0
# 83     0
# 106    0
# Name: Genre, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_test, y_test)
# Out:
# LinearRegression()

# %%
print(regressor.intercept_)
# Out:
# -3.3306690738754696e-16

# %%
print(regressor.intercept_)
# Out:
# [ 1.00000000e+00  6.33857115e-18  4.16063034e-18 -3.47156942e-19]

# %%
y_pred = regressor.predict(x_test)

# %%
y_test
# Out:
# 18     1
# 170    1
# 107    1
# 98     1
# 177    1
# 182    1
# 5      0
# 146    1
# 12     0
# 152    0
# 61     1
# 125    0
# 180    0
# 154    0
# 80     1
# 7      0
# 33     1
# 130    1
# 37     0
# 74     1
# 183    0
# 145    1
# 45     0
# 159    0
# 60     1
# 123    1
# 179    1
# 185    1
# 122    0
# 44     0
# 16     0
# 55     1
# 150    1
# 111    0
# 22     0
# 189    0
# 129    1
# 4      0
# 83     0
# 106    0
# Name: Genre, dtype: int64

# %%
y_pred
# Out:
# array([ 1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00, -1.49271554e-16,  1.00000000e+00,
#         1.12575472e-16,  2.63416251e-16,  1.00000000e+00,  1.27941838e-16,
#         2.93932346e-16,  2.83820592e-16,  1.00000000e+00, -1.45021177e-16,
#         1.00000000e+00,  1.00000000e+00, -2.67907980e-17,  1.00000000e+00,
#         2.27943619e-16,  1.00000000e+00, -4.12418177e-17,  1.56276937e-16,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.87424330e-16,  1.30067268e-16, -3.59941729e-17,  1.00000000e+00,
#         1.00000000e+00,  3.07391811e-17,  6.07873394e-17,  2.94158239e-16,
#         1.00000000e+00, -7.97267636e-17,  1.67906499e-16,  3.30040653e-16])

# %%
df=pd.DataFrame({'Actual':[y_test],'Predicted':[y_pred]})
df
# Out:
#                                               Actual                                          Predicted
# 0  18     1
# 170    1
# 107    1
# 98     1
# 177    1
# 1...  [0.9999999999999999, 1.0, 0.9999999999999999, ...

# %%
df1=['y_test']
df1
# Out:
# ['y_test']

# %%
import matplotlib.pyplot as plt
plt.plot(y_test, y_pred)
plt.title('Actual vs Predicted')
plt.xlabel('Actual')
plt.ylabel('predicted')
plt.show()

# %%
from sklearn import metrics
print('Mean absolute error',metrics.mean_absolute_error(y_test,y_pred))
print('Mean squared error',metrics.mean_squared_error(y_test,y_pred))
print('Root mean squared error',np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# Mean absolute error 1.2303584216090364e-16
# Mean squared error 2.55151455363774e-32
# Root mean squared error 1.5973460970114586e-16

# %%
df=pd.DataFrame({'Actual':y_test,'Predicted':y_pred})
df
# Out:
#      Actual     Predicted
# 18        1  1.000000e+00
# 170       1  1.000000e+00
# 107       1  1.000000e+00
# 98        1  1.000000e+00
# 177       1  1.000000e+00
# 182       1  1.000000e+00
# 5         0 -1.492716e-16
# 146       1  1.000000e+00
# 12        0  1.125755e-16
# 152       0  2.634163e-16
# 61        1  1.000000e+00
# 125       0  1.279418e-16
# 180       0  2.939323e-16
# 154       0  2.838206e-16
# 80        1  1.000000e+00
# 7         0 -1.450212e-16
# 33        1  1.000000e+00
# 130       1  1.000000e+00
# 37        0 -2.679080e-17
# 74        1  1.000000e+00
# 183       0  2.279436e-16
# 145       1  1.000000e+00
# 45        0 -4.124182e-17
# 159       0  1.562769e-16
# 60        1  1.000000e+00
# 123       1  1.000000e+00
# 179       1  1.000000e+00
# 185       1  1.000000e+00
# 122       0  1.874243e-16
# 44        0  1.300673e-16
# 16        0 -3.599417e-17
# 55        1  1.000000e+00
# 150       1  1.000000e+00
# 111       0  3.073918e-17
# ...

# %%
mall_select = mall.replace({ 'Gender': {'Male':0 , 'Female':1}} )

# %%
mall_select
# Out:
#      CustomerID  Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1      1   19                  15                      39
# 1             2      1   21                  15                      81
# 2             3      0   20                  16                       6
# 3             4      0   23                  16                      77
# 4             5      0   31                  17                      40
# ..          ...    ...  ...                 ...                     ...
# 195         196      0   35                 120                      79
# 196         197      0   45                 126                      28
# 197         198      1   32                 126                      74
# 198         199      1   32                 137                      18
# 199         200      1   30                 137                      83
#
# [200 rows x 5 columns]

# %%
mall_select.drop(["CustomerID"], axis=1,inplace=True)

# %%
mall_select
# Out:
#      Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0        1   19                  15                      39
# 1        1   21                  15                      81
# 2        0   20                  16                       6
# 3        0   23                  16                      77
# 4        0   31                  17                      40
# ..     ...  ...                 ...                     ...
# 195      0   35                 120                      79
# 196      0   45                 126                      28
# 197      1   32                 126                      74
# 198      1   32                 137                      18
# 199      1   30                 137                      83
#
# [200 rows x 4 columns]

# %%
corr = mall_select.corr()
corr.shape
# Out:
# (4, 4)

# %%
plt.figure(figsize=(20,20))
sns.heatmap(corr, cbar=True, square= True, annot=True, annot_kws={'size':20}, cmap='YlGnBu')

# %%
plt.figure(figsize = (9,5))
sns.countplot(mall.Genre)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
